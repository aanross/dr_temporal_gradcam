# %% [markdown]
# # Diabetic Retinopathy Temporal GradCAM Benchmark

# %%
# Clone the repository
# !git clone https://github.com/aanross/dr_temporal_gradcam.git
# %cd dr_temporal_gradcam
# !pip install -r requirements.txt

# %%
# Generate mock datasets
# !python mock_data.py

# %%
# Run the main benchmark script
# !bash run_benchmark.sh

# %%
import os
print("Results generated in results/ directory:")
print(os.listdir("results"))
