# %% [markdown]
# # Diabetic Retinopathy Temporal GradCAM Benchmark

# %%
# Clone the repository (Replace YOUR_GITHUB_USERNAME and YOUR_REPO_NAME with your actual info)\n!git clone https://github.com/YOUR_GITHUB_USERNAME/YOUR_REPO_NAME.git\n%cd YOUR_REPO_NAME\n!pip install -r requirements.txt

# %%
# Generate mock datasets\n!python mock_data.py

# %%
# Run the main benchmark script\n!bash run_benchmark.sh

# %%
import os\nprint("Results generated in results/ directory:")\nprint(os.listdir("results"))
